# %% [markdown]
# ## <font color= 'red'> Ciclo 00 - Planejamento - Metodo IOT

# %% [markdown]
# ## <font color= 'red'> Ciclo 01 - Métricas de Validação de Clusters

# %% [markdown]
# 1. Feature Engineering
#     - Recencia
#     - Frequencia
#     - Monetização
#
#
# 2. Métricas de validação de Clustering
#     - WSS (Within - Cluster Sum od Squate)
#     - SS (Silhouette Score)
#
#
# 3. Cluster Analysis
#     - Plot 3d
#     - Cluster Profile

# %% [markdown]
# ## <font color= 'red'> Ciclo 02 - Analise de Silhouette

# %% [markdown]
# 1. Feature Engineering
#     - Average Ticket
#
#
# 2. Análise de Silhouette
#     - Silhouette Analysis
#
#
# 3. Cluster Visualization
#     - UMAP
#
#
# 4. Cluster Analise de Perfil
#     - Descrição dos Centróides

# %% [markdown]
# ## <font color= 'red'> Ciclo 03 - Statistical Descriptive

# %% [markdown]
# 1. Análise Descritiva
#     - Atributos numéricos
#     - Atributos categóricos
#
#
# 2. Feature Engineering
#     - Avarege Recency
#     - Number of Returns
#
#
# 3. Data Preparation
#     - Standard Scaler

# %% [markdown]
# # Planejamento da Solução (IOT)
#
# ###### - Input (Entrada).
#     a - Problema de Negocio
#     b - Questões que serão respondidas
#     c - Dados de entrada / Fonte  de Dados
#
# ###### - Output( Saída ).
#     a - Anásile de dados
#     b - Algoritmo de Machine Learning treinado
#     c - Dashboard
#
# ###### - Tasks (Tarefas).
#     a - Plano de Execução
#     b - Ferramentas

# %% [markdown]
# # PA005 : High Value Customer Identification (Insiders)

# %% [markdown]
# ## 0.0. Planejamento da solução (IOT)

# %% [markdown]
# ### Input - Entrada

# %% [markdown]
# 1. Problema de Negócio
#     - Selecionar os clientes mais valiosos para integrar um programa de Fidelização
#
# 2. Conjunto de dados
#     - Vendas de um e-commerce online, durante o periodo de um ano.

# %% [markdown]
# ### Output - Saída

# %% [markdown]
# 1. A indicação das pessoas que farão parte do programa de Insiders
#  - Lista:   client_id | is_insider|
#
#                10323 | yes/1
#                32413 | no/0

# %% [markdown]
# ### Tasks - Tarefas

# %% [markdown]
# 1. Quem são as pessoas elegíveis para participar do programa de Insiders ?
#     - O que é ser elegivel? O que são clientes de maior "Valor".
#
#         - Faturamento
#
#             - Alto Ticket Médio
#             - Alto LTV ( Life time value )
#             - Baixa Recência
#             - Alto basket size
#             - Baixa probabilidade de churn.
#             - Previsão de LTV
#             - Alta propensão de compra.
#
#         - Custo
#
#             - Baixo taxa de devolução
#
#         - Experiência de compra
#
#             - Média alta das avaliações
#
# 2. Quantos Clientes farão parte do grupo ?
#     - Número total de clientes
#     - % de Insiders
#
# 3. Quais as principais caracteristicas desses clientes ?
#     - Escrever caracteristivas do cliente
#
#         - Idade
#         - Localização
#
#     - Escrever caracteristicas de consumo
#
#         - Atributos da clusterização
#
# 4. Qual a porcentagem de contribuição do faturamento desse grupo para os proximos mese ?
#     - Faturamento total do ano
#     - Faturamento do grupo Insiders
#
# 5. Qual a expectativa de faturamento desse grupo para os proximos meses ?
#     - LTV do grupo Insiders
#     - Analise de Cohort
#
# 6. Quais as condições para uma pessoa ser elegivel ao Insiders ?
#     - Definir a periodicidade (1 mes, 3 meses)
#     - A pessoa precisa ser similar ou pareceido com uma pessoa do grupo.
#
# 7. Quais as condições para uma pessoa ser removida do Insiders ?
#     - Definir a periodicidade (1 mes, 3 meses)
#     - A pessoa precisa ser desimilar ou não pareceido com uma pessoa do grupo.
#
# 8. Qual a garantia que o programa Insiders é melhor que o restante da base?
#     - Teste A/B
#     - Teste A/B Bayesiano
#     - Teste de hipóteses.
#
# 9. Quais ações o time de marketing pode realizar para aumentar o faturamento?
#     - Desconto
#     - Preferencia de compra
#     - Frete
#     - Visista a empresa

# %% [markdown]
# # <font color='red'> 1.0. Imports </font>

# %%
import pandas as pd
import seaborn as sns
import inflection
import warnings
import regex as re
import numpy as np

#import umap.umap_ as umap
from sklearn import cluster as cl
from sklearn import preprocessing as pp
from sklearn import metrics as m
from sklearn import decomposition as dd
from sklearn.manifold import TSNE

from sklearn.cluster import DBSCAN


from matplotlib import pyplot as plt
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from IPython.display import HTML

from ydata_profiling import ProfileReport

from plotly import express as px

# %% [markdown]
# ## 0.1. Help Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
warnings.filterwarnings( 'ignore' )

# %%
import matplotlib.pyplot as plt

# Definir as configurações padrão
plt.rcParams['figure.figsize'] = [18, 9]  # Tamanho padrão da figura
plt.rcParams['figure.dpi'] = 100  # DPI padrão da figura
plt.rcParams['axes.grid'] = True  # Exibir linhas de grade nos gráficos
plt.rcParams['font.size'] = 12  # Tamanho da fonte padrão
plt.rcParams['axes.labelsize'] = 12  # Tamanho da fonte dos rótulos dos eixos
plt.rcParams['axes.titlesize'] = 14  # Tamanho da fonte dos títulos dos gráficos
plt.rcParams['legend.fontsize'] = 10  # Tamanho da fonte da legenda
plt.rcParams['xtick.labelsize'] = 10  # Tamanho da fonte dos rótulos do eixo x
plt.rcParams['ytick.labelsize'] = 10  # Tamanho da fonte dos rótulos do eixo y

# %% [markdown]
# ## 0.2 Load Dataset

# %%
df_raw = pd.read_csv('Ecommerce.csv',encoding='unicode_escape')

# %%
df_raw
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country  Unnamed: 8
# 0        29-Nov-16       2.55     17850.0  United Kingdom         NaN
# 1        29-Nov-16       3.39     17850.0  United Kingdom         NaN
# 2        29-Nov-16       2.75     17850.0  United Kingdom         NaN
# 3        29-Nov-16       3.39     17850.0  United Kingdom         NaN
# 4        29-Nov-16       3.39     17850.0  United Kingdom         NaN
# ...            ...        ...         ...             ...         ...
# 541904    7-Dec-17       0.85     12680.0          France         NaN
# 541905    7-Dec-17       2.10     12680.0          France         NaN
# 541906    7-Dec-17       4.15     12680.0          France         NaN
# 541907    7-Dec-17       4.15     12680.0          France         NaN
# 541908    7-Dec-17       4.95     12680.0          France         NaN
#
# [541909 rows x 9 columns]

# %%
#Excluindo a coluna unnamed
df_raw.drop(columns=['Unnamed: 8'], axis=1, inplace=True)

# %% [markdown]
# # <font color='red'> 2.0. Descrição dos dados. </font>

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## 2.1. Rename Columns

# %%
df_raw.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
cols_old = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate','UnitPrice', 'CustomerID', 'Country']

snakecase = lambda x: inflection.underscore( x )

cols_new = list( map( snakecase, cols_old ) )

# rename
df1.columns = cols_new

# %%
df1.sample()
# Out:
#        invoice_no stock_code                    description  quantity  \
# 208002     555076      23284  DOORMAT KEEP CALM AND COME IN         2
#
#        invoice_date  unit_price  customer_id         country
# 208002    29-May-17        7.95      13900.0  United Kingdom

# %% [markdown]
# ## 2.2. Data Dimensions

# %%
print(f'Numero de linhas: {df1.shape[0]}')
print(f'Numero de colunas: {df1.shape[1]}')
# Out:
# Numero de linhas: 541909
# Numero de colunas: 8

# %% [markdown]
# ## 2.3. Data types

# %%
df1.dtypes
# Out:
# invoice_no       object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price  customer_id         country
# 0    29-Nov-16        2.55      17850.0  United Kingdom
# 1    29-Nov-16        3.39      17850.0  United Kingdom
# 2    29-Nov-16        2.75      17850.0  United Kingdom
# 3    29-Nov-16        3.39      17850.0  United Kingdom
# 4    29-Nov-16        3.39      17850.0  United Kingdom

# %% [markdown]
# ## 2.4. Check NA

# %%
df1.isna().sum()
# Out:
# invoice_no           0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %% [markdown]
# ## 2.5. Replace NA

# %%
df_missing = df1.loc[df1['customer_id'].isna(), :]
df_not_missing = df1.loc[~df1['customer_id'].isna(), :]

# %% [markdown]
# ##### Verificando se existe algum invoice_no repetido entre as bases

# %%
missing_invoice = df_missing['invoice_no'].drop_duplicates().tolist()
missing_invoice[:10]
# Out:
# ['536414',
#  '536544',
#  '536545',
#  '536546',
#  '536547',
#  '536549',
#  '536550',
#  '536552',
#  '536553',
#  '536554']

# %%
df_not_missing.loc[df_not_missing['invoice_no'].isin(missing_invoice), :].head()
# Out:
# Empty DataFrame
# Columns: [invoice_no, stock_code, description, quantity, invoice_date, unit_price, customer_id, country]
# Index: []

# %% [markdown]
# - Não existe invoice_no correspondente

# %% [markdown]
# ##### Create Reference

# %%
df_backup = pd.DataFrame(df_missing['invoice_no'].drop_duplicates())
df_backup['customer_id'] = np.arange(19000, 19000+len(df_backup), 1)

# %%
df_backup.head()
# Out:
#      invoice_no  customer_id
# 622      536414        19000
# 1443     536544        19001
# 1970     536545        19002
# 1971     536546        19003
# 1972     536547        19004

# %% [markdown]
# ##### Merge original with reference dataframe

# %%
df1 = pd.merge(df1, df_backup,  on= 'invoice_no', how='left')
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price  customer_id_x         country  customer_id_y
# 0    29-Nov-16        2.55        17850.0  United Kingdom            NaN
# 1    29-Nov-16        3.39        17850.0  United Kingdom            NaN
# 2    29-Nov-16        2.75        17850.0  United Kingdom            NaN
# 3    29-Nov-16        3.39        17850.0  United Kingdom            NaN
# 4    29-Nov-16        3.39        17850.0  United Kingdom            NaN

# %% [markdown]
# ##### Coalesce

# %%
df1['customer_id'] = df1['customer_id_x'].combine_first(df1['customer_id_y'])
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price  customer_id_x         country  customer_id_y  \
# 0    29-Nov-16        2.55        17850.0  United Kingdom            NaN
# 1    29-Nov-16        3.39        17850.0  United Kingdom            NaN
# 2    29-Nov-16        2.75        17850.0  United Kingdom            NaN
# 3    29-Nov-16        3.39        17850.0  United Kingdom            NaN
# 4    29-Nov-16        3.39        17850.0  United Kingdom            NaN
#
#    customer_id
# 0      17850.0
# 1      17850.0
# 2      17850.0
# 3      17850.0
# 4      17850.0

# %% [markdown]
# ##### Drop Extra Columns

# %%
df1 = df1.drop(columns = ['customer_id_x', 'customer_id_y'], axis=1)
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price         country  customer_id
# 0    29-Nov-16        2.55  United Kingdom      17850.0
# 1    29-Nov-16        3.39  United Kingdom      17850.0
# 2    29-Nov-16        2.75  United Kingdom      17850.0
# 3    29-Nov-16        3.39  United Kingdom      17850.0
# 4    29-Nov-16        3.39  United Kingdom      17850.0

# %%
df1.isna().sum()
# Out:
# invoice_no         0
# stock_code         0
# description     1454
# quantity           0
# invoice_date       0
# unit_price         0
# country            0
# customer_id        0
# dtype: int64

# %%
#df1 = df1.dropna(subset=['description', 'customer_id'])

#print(f'{ (1 -df1.shape[0]/ df_raw.shape[0]) * 100:.2f} % dos dados foram removidos')

# %% [markdown]
# ## 2.6. Change dtypes

# %%
#invoice_date
df1['invoice_date'] = pd.to_datetime(df1['invoice_date'], format='%d-%b-%y')
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price         country  customer_id
# 0   2016-11-29        2.55  United Kingdom      17850.0
# 1   2016-11-29        3.39  United Kingdom      17850.0
# 2   2016-11-29        2.75  United Kingdom      17850.0
# 3   2016-11-29        3.39  United Kingdom      17850.0
# 4   2016-11-29        3.39  United Kingdom      17850.0

# %%
#customer_id
df1['customer_id'] = df1['customer_id'].astype(int)
df1.head()
# Out:
#   invoice_no stock_code                          description  quantity  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   invoice_date  unit_price         country  customer_id
# 0   2016-11-29        2.55  United Kingdom        17850
# 1   2016-11-29        3.39  United Kingdom        17850
# 2   2016-11-29        2.75  United Kingdom        17850
# 3   2016-11-29        3.39  United Kingdom        17850
# 4   2016-11-29        3.39  United Kingdom        17850

# %%
df1.dtypes
# Out:
# invoice_no              object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# country                 object
# customer_id              int32
# dtype: object

# %% [markdown]
# ## 2.7. Descriptive Statistics

# %% [markdown]
# ### 2.7.1 Numerical attributs

# %%
num_atributes = df1.select_dtypes(include=['int64', 'float64'])

cat_atributes = df1.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]'])

# %%
# central tendency - mean, median
ct1 = pd.DataFrame(num_atributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_atributes.apply(np.median)).T

#dispersion - desvio padrão, minimo, range, skew, kurtosis
d1 = pd.DataFrame(num_atributes.apply(np.std)).T
d2 = pd.DataFrame(num_atributes.apply(np.min)).T
d3 = pd.DataFrame(num_atributes.apply(np.max)).T
d4 = pd.DataFrame(num_atributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_atributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_atributes.apply(lambda x: x.kurtosis())).T


#concatenate
c = pd.concat([d2, d3, d4, ct1, ct2, d2, d5, d6]).T.reset_index()
c.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']

# %%
c
# Out:
#    attributes       min      max      range      mean  median       std  \
# 0    quantity -80995.00  80995.0  161990.00  9.552250    3.00 -80995.00
# 1  unit_price -11062.06  38970.0   50032.06  4.611114    2.08 -11062.06
#
#          skew       kurtosis
# 0   -0.264076  119769.160031
# 1  186.506972   59005.719097

# %% [markdown]
# #### 2.7.1.1 Numerical attributs investigating

# %% [markdown]
# - Podemos ver que na quantida temos um valor negativo (**pode ser devolução**)
# - Quantidade máxima, temos uma pessoa que comprou 80995 produtos
# - Valor unitário, temos o valor de 0

# %%
cat_atributes.head()
# Out:
#   invoice_no stock_code                          description         country  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# 1     536365      71053                  WHITE METAL LANTERN  United Kingdom
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER  United Kingdom
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE  United Kingdom
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.  United Kingdom
#
#    customer_id
# 0        17850
# 1        17850
# 2        17850
# 3        17850
# 4        17850

# %%
#invoice number

len(df1.loc[df1['invoice_no'].apply(lambda x: bool(re.search('[^0-9]+', x))), 'invoice_no'].drop_duplicates())
# Out:
# 3839

# %%
#stock Code
#len(df1.loc[df1['stock_code'].apply(lambda x: bool(re.search('[^0-9]+', x))), 'stock_code'].drop_duplicates())

df1.loc[df1['stock_code'].apply(lambda x: bool(re.search('^[a-zA-Z]+$', x))), :].head(20)
# Out:
#      invoice_no stock_code     description  quantity invoice_date  unit_price  \
# 45       536370       POST         POSTAGE         3   2016-11-29       18.00
# 141     C536379          D        Discount        -1   2016-11-29       27.50
# 386      536403       POST         POSTAGE         1   2016-11-29       15.00
# 1123     536527       POST         POSTAGE         1   2016-11-29       18.00
# 1814     536544        DOT  DOTCOM POSTAGE         1   2016-11-29      569.77
# 2239     536569          M          Manual         1   2016-11-29        1.25
# 2250     536569          M          Manual         1   2016-11-29       18.95
# 3041     536592        DOT  DOTCOM POSTAGE         1   2016-11-29      607.49
# 5073     536840       POST         POSTAGE         1   2016-11-30       18.00
# 5258     536852       POST         POSTAGE         1   2016-12-01       18.00
# 5325     536858       POST         POSTAGE         2   2016-12-01       40.00
# 5369     536861       POST         POSTAGE         3   2016-12-01       18.00
# 5450     536862        DOT  DOTCOM POSTAGE         1   2016-12-01      254.43
# 5545     536864        DOT  DOTCOM POSTAGE         1   2016-12-01      121.06
# 5684     536865          M          Manual         1   2016-12-01        2.55
# 5685     536865        DOT  DOTCOM POSTAGE         1   2016-12-01      498.47
# 6165     536876        DOT  DOTCOM POSTAGE         1   2016-12-01      887.52
# 6602     536967       POST         POSTAGE         1   2016-12-01       18.00
# 6676     536974       POST         POSTAGE         2   2016-12-01       18.00
# 6798     536981          M          Manual         2   2016-12-01        0.85
#
#              country  customer_id
# 45            France        12583
# 141   United Kingdom        14527
# 386      Netherlands        12791
# 1123         Germany        12662
# 1814  United Kingdom        19001
# 2239  United Kingdom        16274
# 2250  United Kingdom        16274
# 3041  United Kingdom        19014
# 5073         Germany        12738
# 5258          France        12686
# 5325     Switzerland        13520
# 5369         Germany        12427
# 5450  United Kingdom        19023
# 5545  United Kingdom        19024
# 5684  United Kingdom        19025
# 5685  United Kingdom        19025
# 6165  United Kingdom        19027
# 6602         Germany        12600
# 6676          France        12682
# 6798  United Kingdom        14723

# %% [markdown]
# ### 2.7.2. Categorical Attributes

# %% [markdown]
# ##### invoice_no

# %%
# problema: Temos invoice_no com letras e numeros

df_letter_invoice = df1.loc[df1['invoice_no'].apply(lambda x: bool(re.search('[^0-9]+', x))), :]
df_letter_invoice.head()

print(f'Total number of invoices: {len(df_letter_invoice)}')
print(f'Total number of negative quantity: {len(df_letter_invoice.query("quantity < 0"))}')
# Out:
# Total number of invoices: 9291
# Total number of negative quantity: 9288

# %% [markdown]
# ##### stock_code

# %%
# check stock code only characters

print(df1.loc[df1['stock_code'].apply(lambda x: bool(re.search('^[a-zA-Z]+$', x))), 'stock_code'].unique())
#sotck_code != [post, D, M, DOT, CRUK]
# Out:
# ['POST' 'D' 'DOT' 'M' 'S' 'AMAZONFEE' 'm' 'DCGSSBOY' 'DCGSSGIRL' 'PADS'
#  'B' 'CRUK']

# %% [markdown]
# ##### Descripition

# %% [markdown]
# ##### Country

# %%
df1['country'].value_counts(normalize=True)
# Out:
# United Kingdom          0.914320
# Germany                 0.017521
# France                  0.015790
# EIRE                    0.015124
# Spain                   0.004674
# Netherlands             0.004375
# Belgium                 0.003818
# Switzerland             0.003694
# Portugal                0.002803
# Australia               0.002323
# Norway                  0.002004
# Italy                   0.001482
# Channel Islands         0.001399
# Finland                 0.001283
# Cyprus                  0.001148
# Sweden                  0.000853
# Unspecified             0.000823
# Austria                 0.000740
# Denmark                 0.000718
# Japan                   0.000661
# Poland                  0.000629
# Israel                  0.000548
# USA                     0.000537
# Hong Kong               0.000531
# Singapore               0.000423
# Iceland                 0.000336
# Canada                  0.000279
# Greece                  0.000269
# Malta                   0.000234
# United Arab Emirates    0.000125
# European Community      0.000113
# RSA                     0.000107
# Lebanon                 0.000083
# Lithuania               0.000065
# Brazil                  0.000059
# Czech Republic          0.000055
# Bahrain                 0.000035
# Saudi Arabia            0.000018
# Name: country, dtype: float64

# %% [markdown]
# # <font color='red'> 3.0. Filtragem de Variáveis </font>

# %%
df2 = df1.copy()

# %% [markdown]
# #### Numerical Attributes

# %%
df2 = df2.loc[df2['unit_price'] >= 0.04, :]

# %% [markdown]
# #### Categorical Attributes

# %%
#sotck_code != [post, D, M, DOT, CRUK]

df2 = df2[~df2['stock_code'].isin(['POST' 'D' 'DOT' 'M' 'S' 'AMAZONFEE' 'm' 'DCGSSBOY' 'DCGSSGIRL' 'PADS'
 'B' 'CRUK'])]

# %%
#Descripition
df2= df2.drop(columns='description', axis=1)

# %%
#Country
df2 = df2[~df2['country'].isin(['European Community', 'Unspecified'])]

# %%
#bad users
df2 = df2[~df2['customer_id'].isin([16446])]

# %%
df2_returns = df2.loc[df2['quantity'] < 0, :]
df2_purchases = df2.loc[df2['quantity'] >= 0, :]

# %%
df2_returns
# Out:
#        invoice_no stock_code  quantity invoice_date  unit_price  \
# 141       C536379          D        -1   2016-11-29       27.50
# 154       C536383     35004C        -1   2016-11-29        4.65
# 235       C536391      22556       -12   2016-11-29        1.65
# 236       C536391      21984       -24   2016-11-29        0.29
# 237       C536391      21983       -24   2016-11-29        0.29
# ...           ...        ...       ...          ...         ...
# 540449    C581490      23144       -11   2017-12-07        0.83
# 541541    C581499          M        -1   2017-12-07      224.69
# 541715    C581568      21258        -5   2017-12-07       10.95
# 541716    C581569      84978        -1   2017-12-07        1.25
# 541717    C581569      20979        -5   2017-12-07        1.25
#
#                country  customer_id
# 141     United Kingdom        14527
# 154     United Kingdom        15311
# 235     United Kingdom        17548
# 236     United Kingdom        17548
# 237     United Kingdom        17548
# ...                ...          ...
# 540449  United Kingdom        14397
# 541541  United Kingdom        15498
# 541715  United Kingdom        15311
# 541716  United Kingdom        17315
# 541717  United Kingdom        17315
#
# [9282 rows x 7 columns]

# %% [markdown]
# # <font color='red'> 4.0. Feature Enginering </font>

# %% [markdown]
# ## 4.1. Feature Creation

# %%
df2
# Out:
#        invoice_no stock_code  quantity invoice_date  unit_price  \
# 0          536365     85123A         6   2016-11-29        2.55
# 1          536365      71053         6   2016-11-29        3.39
# 2          536365     84406B         8   2016-11-29        2.75
# 3          536365     84029G         6   2016-11-29        3.39
# 4          536365     84029E         6   2016-11-29        3.39
# ...           ...        ...       ...          ...         ...
# 541904     581587      22613        12   2017-12-07        0.85
# 541905     581587      22899         6   2017-12-07        2.10
# 541906     581587      23254         4   2017-12-07        4.15
# 541907     581587      23255         4   2017-12-07        4.15
# 541908     581587      22138         3   2017-12-07        4.95
#
#                country  customer_id
# 0       United Kingdom        17850
# 1       United Kingdom        17850
# 2       United Kingdom        17850
# 3       United Kingdom        17850
# 4       United Kingdom        17850
# ...                ...          ...
# 541904          France        12680
# 541905          France        12680
# 541906          France        12680
# 541907          France        12680
# 541908          France        12680
#
# [538873 rows x 7 columns]

# %%
df_ref = df2[['customer_id']].drop_duplicates(ignore_index=True)
df_ref.head()
# Out:
#    customer_id
# 0        17850
# 1        13047
# 2        12583
# 3        13748
# 4        15100

# %% [markdown]
# ### Gross Revenue

# %%
#Faturamento = Quantity * price
df2_purchases['gross_revenue'] = df2_purchases['quantity'] * df2_purchases['unit_price']


#Monetary
df2_purchases[['customer_id', 'gross_revenue']].head()


df_monetary = df2_purchases[['customer_id', 'gross_revenue']].groupby('customer_id').sum().reset_index()

#merge com o df_ref

df_ref = pd.merge(df_ref, df_monetary, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id        0
# gross_revenue    215
# dtype: int64

# %% [markdown]
# ### Recency

# %%
#Recency
df_recency = df2_purchases[['customer_id', 'invoice_date']].groupby('customer_id').max().reset_index()
df_recency['recency_days'] = (df2_purchases['invoice_date'].max() - df_recency['invoice_date']).dt.days
df_recency = df_recency[['customer_id', 'recency_days']].copy()


df_ref = pd.merge(df_ref, df_recency, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id        0
# gross_revenue    215
# recency_days     215
# dtype: int64

# %% [markdown]
# ### quantity of purchased

# %%
df_frequency = (df2_purchases[['customer_id', 'invoice_no']].drop_duplicates()
                                                            .groupby('customer_id')
                                                            .count()
                                                            .reset_index()
                                                            .rename(columns={'invoice_no': 'qtde_invoices'}))
df_frequency.head()
# Out:
#    customer_id  qtde_invoices
# 0        12346              1
# 1        12347              7
# 2        12348              4
# 3        12349              1
# 4        12350              1

# %%
df_frequency = df2_purchases[['customer_id', 'invoice_no']].drop_duplicates().groupby('customer_id').count().reset_index()
df_frequency.head()
# Out:
#    customer_id  invoice_no
# 0        12346           1
# 1        12347           7
# 2        12348           4
# 3        12349           1
# 4        12350           1

# %%
df_ref = pd.merge(df_ref, df_frequency, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id        0
# gross_revenue    215
# recency_days     215
# invoice_no       215
# dtype: int64

# %% [markdown]
# ### Quantity of items purchased

# %%
df_frequency = (df2_purchases[['customer_id', 'quantity']].groupby('customer_id')
                                                          .sum()
                                                          .reset_index()
                                                          .rename(columns={'quantity': 'qtde_items'}))
df_frequency.head()
# Out:
#    customer_id  qtde_items
# 0        12346       74215
# 1        12347        2458
# 2        12348        2341
# 3        12349         631
# 4        12350         197

# %%
df_ref = pd.merge(df_ref, df_frequency, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id        0
# gross_revenue    215
# recency_days     215
# invoice_no       215
# qtde_items       215
# dtype: int64

# %% [markdown]
# ### Quantity of products purchased

# %%
df_freq = (df2_purchases.loc[:, ['customer_id', 'stock_code']].groupby('customer_id').nunique()
                                                              .reset_index()
                                                              .rename(columns={'stock_code': 'qtde_produto'}))
df_freq
# Out:
#       customer_id  qtde_produto
# 0           12346             1
# 1           12347           103
# 2           12348            22
# 3           12349            73
# 4           12350            17
# ...           ...           ...
# 5750        22705             2
# 5751        22706           635
# 5752        22707           731
# 5753        22708            56
# 5754        22709           218
#
# [5755 rows x 2 columns]

# %%
df_ref = pd.merge(df_ref, df_freq, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id        0
# gross_revenue    215
# recency_days     215
# invoice_no       215
# qtde_items       215
# qtde_produto     215
# dtype: int64

# %% [markdown]
# ### AVG Ticket Value

# %%
df_avg_ticket = df2_purchases[['customer_id', 'gross_revenue']].groupby('customer_id').mean().reset_index().rename(columns={'gross_revenue' : 'avg_ticket'})
df_avg_ticket.head()
# Out:
#    customer_id    avg_ticket
# 0        12346  77183.600000
# 1        12347     23.681319
# 2        12348     57.975484
# 3        12349     24.076027
# 4        12350     19.670588

# %%
df_ref = pd.merge(df_ref, df_avg_ticket, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id        0
# gross_revenue    215
# recency_days     215
# invoice_no       215
# qtde_items       215
# qtde_produto     215
# avg_ticket       215
# dtype: int64

# %% [markdown]
# ###  Average Recency Days

# %%
df_aux = df2[['customer_id', 'invoice_date']].drop_duplicates().sort_values(['customer_id','invoice_date'], ascending=[True, True])
df_aux['next_customer_id'] = df_aux['customer_id'].shift()
df_aux['previous_date'] = df_aux['invoice_date'].shift()

df_aux['avg_recency_days'] = df_aux.apply(lambda x: (x['invoice_date'] - x['previous_date']).days if x['customer_id'] == x['next_customer_id'] else np.nan, axis=1)


df_aux = df_aux.drop(['invoice_date', 'next_customer_id', 'previous_date'], axis=1).dropna()

df_avg_recency_days = df_aux.groupby('customer_id').mean().reset_index()


df_ref = pd.merge(df_ref, df_avg_recency_days, on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id            0
# gross_revenue        215
# recency_days         215
# invoice_no           215
# qtde_items           215
# qtde_produto         215
# avg_ticket           215
# avg_recency_days    2984
# dtype: int64

# %% [markdown]
# ### Frequency Purchase

# %%
df_aux = (df2_purchases[['customer_id', 'invoice_no', 'invoice_date']].drop_duplicates()
                                                            .groupby('customer_id')
                                                            .agg(max_ = ('invoice_date', 'max'),
                                                                 min_ = ('invoice_date', 'min'),
                                                                 days_ = ('invoice_date', lambda x:( (x.max() - x.min()).days)+1),
                                                                 buy_ = ('invoice_no', 'count'))).reset_index()
          
df_aux['frequency'] = df_aux[['buy_', 'days_']].apply(lambda x: x['buy_'] / x['days_'] if x['days_'] != 0 else 0, axis=1)

df_ref = pd.merge(df_ref, df_aux[['customer_id', 'frequency']], on='customer_id', how='left')
df_ref.isna().sum()
# Out:
# customer_id            0
# gross_revenue        215
# recency_days         215
# invoice_no           215
# qtde_items           215
# qtde_produto         215
# avg_ticket           215
# avg_recency_days    2984
# frequency            215
# dtype: int64

# %%
df_aux.sort_values('frequency', ascending=False).head()
# Out:
#       customer_id       max_       min_  days_  buy_  frequency
# 4010        17850 2016-11-30 2016-11-29      2    34       17.0
# 2763        16120 2017-10-09 2017-10-09      1     4        4.0
# 2622        15920 2017-07-06 2017-07-06      1     4        4.0
# 2008        15098 2017-06-08 2017-06-08      1     3        3.0
# 2674        16000 2017-12-05 2017-12-05      1     3        3.0

# %% [markdown]
# ### <font color = 'green'> Number of Returns

# %%
df_returns = df2_returns[['customer_id', 'quantity']].groupby('customer_id').sum().reset_index().rename(columns={'quantity':'qtde_returns'})
df_returns['qtde_returns'] = df_returns['qtde_returns']* -1

df_ref = pd.merge(df_ref, df_returns, how='left', on='customer_id')
df_ref.loc[df_ref['qtde_returns'].isna(), 'qtde_returns']=0
df_ref.isna().sum()
# Out:
# customer_id            0
# gross_revenue        215
# recency_days         215
# invoice_no           215
# qtde_items           215
# qtde_produto         215
# avg_ticket           215
# avg_recency_days    2984
# frequency            215
# qtde_returns           0
# dtype: int64

# %% [markdown]
# ### <font color = 'green'> Basket Size

# %%
df_aux = (df2_purchases.loc[:, ['customer_id', 'invoice_no', 'quantity']].groupby('customer_id')
                                                                         .agg(n_purchases = ('invoice_no', 'nunique'),
                                                                              n_products = ('quantity', 'sum'))
                                                                         .reset_index())

df_aux['avg_basket_size'] = df_aux['n_products'] / df_aux['n_purchases']


df_ref = pd.merge(df_ref, df_aux[['customer_id', 'avg_basket_size']], how='left', on='customer_id' )
df_ref.isna().sum()
# Out:
# customer_id            0
# gross_revenue        215
# recency_days         215
# invoice_no           215
# qtde_items           215
# qtde_produto         215
# avg_ticket           215
# avg_recency_days    2984
# frequency            215
# qtde_returns           0
# avg_basket_size      215
# dtype: int64

# %% [markdown]
# ### <font color = 'green'> Variaty of product

# %%
df_aux = (df2_purchases.loc[:, ['customer_id', 'invoice_no', 'stock_code']].groupby('customer_id')
                                                                         .agg(n_purchases = ('invoice_no', 'nunique'),
                                                                              n_products = ('stock_code', 'nunique'))
                                                                         .reset_index())

df_aux['avg_unique_basket_size'] = df_aux['n_products'] / df_aux['n_purchases']


df_ref = pd.merge(df_ref, df_aux[['customer_id', 'avg_unique_basket_size']], how='left', on='customer_id' )
df_ref.isna().sum()
# Out:
# customer_id                  0
# gross_revenue              215
# recency_days               215
# invoice_no                 215
# qtde_items                 215
# qtde_produto               215
# avg_ticket                 215
# avg_recency_days          2984
# frequency                  215
# qtde_returns                 0
# avg_basket_size            215
# avg_unique_basket_size     215
# dtype: int64

# %%
df_ref.head()
# Out:
#    customer_id  gross_revenue  recency_days  invoice_no  qtde_items  \
# 0        17850        5391.21         372.0        34.0      1733.0
# 1        13047        3237.54          31.0        10.0      1391.0
# 2        12583        7281.38           2.0        15.0      5060.0
# 3        13748         948.25          95.0         5.0       439.0
# 4        15100         876.00         333.0         3.0        80.0
#
#    qtde_produto  avg_ticket  avg_recency_days  frequency  qtde_returns  \
# 0          21.0   18.152222         35.500000  17.000000          40.0
# 1         106.0   18.822907         26.307692   0.029155          36.0
# 2         115.0   29.479271         21.823529   0.040323          51.0
# 3          24.0   33.866071         92.666667   0.017921           0.0
# 4           1.0  292.000000          8.600000   0.073171          22.0
#
#    avg_basket_size  avg_unique_basket_size
# 0        50.970588                0.617647
# 1       139.100000               10.600000
# 2       337.333333                7.666667
# 3        87.800000                4.800000
# 4        26.666667                0.333333

# %%
df3 = df_ref.dropna().copy()

# %% [markdown]
# # <font color='red'> 5.0. EDA </font>

# %% [markdown]
# ## 4.1. Univariate Analysis

# %% [markdown]
# **Notes**
#
#     1. Clusters Coesos - Separados
#     2. Métricas
#         - Min, Máximo, Range(Dispersão)
#         - Média e Mediana
#         - Desvio Padrão
#         - Coeficiente de Variação (CV)
#         - Distribuição

# %%
#profile = ProfileReport(df3)
#profile.to_file('output.html')

# %% [markdown]
# ### 4.1.1. Gross Revenue - OK

# %%
df3[['gross_revenue']].describe()
# Out:
#        gross_revenue
# count    2984.000000
# mean     2726.911387
# std     10195.376976
# min         6.200000
# 25%       573.055000
# 50%      1097.375000
# 75%      2329.457500
# max    280206.020000

# %%
sns.histplot(df3['gross_revenue'],bins=50)
# Out:
# <AxesSubplot:xlabel='gross_revenue', ylabel='Count'>

# %%
df2[df2['customer_id'] == 14646].head()
# Out:
#       invoice_no stock_code  quantity invoice_date  unit_price      country  \
# 37952     539491      21981        12   2016-12-18        0.29  Netherlands
# 37953     539491      21986        12   2016-12-18        0.29  Netherlands
# 37954     539491      22720         2   2016-12-18        4.95  Netherlands
# 37955     539491      21931         1   2016-12-18        1.95  Netherlands
# 37956     539491      22613         2   2016-12-18        0.85  Netherlands
#
#        customer_id
# 37952        14646
# 37953        14646
# 37954        14646
# 37955        14646
# 37956        14646

# %% [markdown]
# ### 4.1.2. Recency Days

# %%
df3[['recency_days']].describe()
# Out:
#        recency_days
# count   2984.000000
# mean      64.494638
# std       77.770220
# min        0.000000
# 25%       11.000000
# 50%       32.000000
# 75%       82.000000
# max      373.000000

# %%
sns.histplot(df3['recency_days'],bins=30)
# Out:
# <AxesSubplot:xlabel='recency_days', ylabel='Count'>

# %% [markdown]
# ### 4.1.3. AVG Ticket

# %%
df3[['avg_ticket']].describe()
# Out:
#         avg_ticket
# count  2984.000000
# mean     32.941300
# std     111.286119
# min       2.150588
# 25%      13.151965
# 50%      18.181007
# 75%      25.310879
# max    4453.430000

# %% [markdown]
# - Temos um AVG Ticket muito alto 56157.50

# %%
df3[df3['avg_ticket'] ==  56157.50]
# Out:
# Empty DataFrame
# Columns: [customer_id, gross_revenue, recency_days, invoice_no, qtde_items, qtde_produto, avg_ticket, avg_recency_days, frequency, qtde_returns, avg_basket_size, avg_unique_basket_size]
# Index: []

# %%
df2[df2['customer_id'] == 16446]
# Out:
# Empty DataFrame
# Columns: [invoice_no, stock_code, quantity, invoice_date, unit_price, country, customer_id]
# Index: []

# %% [markdown]
# - Dá para ver que a mercadoria não chegou a sair da loja poir o invoice_no é seguido, o de compra como o de devolução
# - Vamos remover da base de dados pois pode ter sido um erro do sistema

# %% [markdown]
# ## 4.2. Bivariate Analysis

# %%
cols = ['customer_id']
df32 = df3.drop(cols, axis=1)

# %%
plt.figure(figsize=(25,12))
sns.pairplot(df32)

# %% [markdown]
# **Notas**
# - Frequencia possui pouca variação
# - Avg ticket
# -

# %% [markdown]
# ## <font color = 'green' >  4.3. Estudo do Espaço

# %%
df4 = df3.copy()

# %%
from sklearn import preprocessing as pp

# %%
df41 = df4.drop(cols, axis=1)
mm = pp.MinMaxScaler()

#
df41['gross_revenue'] = mm.fit_transform(df41[['gross_revenue']])
df41['recency_days'] = mm.fit_transform(df41[['recency_days']])
df41['invoice_no'] = mm.fit_transform(df41[['invoice_no']])
df41['qtde_produto'] = mm.fit_transform(df41[['qtde_produto']])
df41['qtde_items'] = mm.fit_transform(df41[['qtde_items']])
#df41['avg_ticket'] = mm.fit_transform(df41[['avg_ticket']])
#df41['avg_recency_days'] = mm.fit_transform(df41[['avg_recency_days']])
df41['frequency'] = mm.fit_transform(df41[['frequency']])
df41['qtde_returns'] = mm.fit_transform(df41[['qtde_returns']])
#df41['avg_basket_size'] = mm.fit_transform(df41[['avg_basket_size']])
#df41['avg_unique_basket_size'] = mm.fit_transform(df41[['avg_unique_basket_size']])

# %%
cols_selected = ['gross_revenue', 'recency_days', 'invoice_no', 'qtde_produto', 'qtde_items', 'frequency', 'qtde_returns']

# %%
X = df41[cols_selected].copy()

# %%
X.shape[1]
# Out:
# 7

# %%
pca = dd.PCA(n_components=X.shape[1])

principal_components = pca.fit_transform(X)

#plot explained variable
features = range(pca.n_components_)

plt.figsize=(16,8)

plt.bar(features, pca.explained_variance_ratio_, color='black')

#pca_components
df_pca = pd.DataFrame(principal_components)

# %%
df_pca
# Out:
#              0         1         2         3         4         5         6
# 0     0.849017  0.148137  0.041514  0.030386  0.641089  0.727939  0.001965
# 1    -0.091739  0.012586 -0.006040  0.003347  0.007536 -0.007487  0.002106
# 2    -0.171426  0.033143  0.008945 -0.003087  0.018297 -0.011460 -0.003933
# 3     0.083953 -0.019519  0.009951 -0.001488  0.006190 -0.014516  0.000153
# 4     0.720234  0.026541  0.001439 -0.002497 -0.004393 -0.030313  0.001391
# ...        ...       ...       ...       ...       ...       ...       ...
# 2979 -0.137308 -0.047301  0.015269  0.001670  0.026567  0.050862 -0.000578
# 2980 -0.148301 -0.048912  0.022777  0.003273  0.027657  0.032566 -0.000836
# 2981 -0.177912  0.058487 -0.085035  0.006374 -0.040719  0.049640  0.002331
# 2982 -0.146134 -0.022333 -0.002119  0.003727  0.061240  0.099069 -0.000247
# 2983 -0.147139 -0.053104  0.029501  0.016905  0.026303  0.050647 -0.000367
#
# [2984 rows x 7 columns]

# %%
sns.scatterplot(x=0, y = 1, data=df_pca)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %% [markdown]
# ### <font color='green'> 4.3.1 t-SNE

# %%
reducer = TSNE(n_components=2, 
            random_state=42,
            n_jobs=-1)

#embedding

embedding = reducer.fit_transform(X )


df_pca['embedding_x2'] = embedding[:,0]
df_pca['embedding_y2'] = embedding[:,1]

#plot
sns.scatterplot(x='embedding_x2', 
                y='embedding_y2',  
                data = df_pca)
# Out:
# <AxesSubplot:xlabel='embedding_x2', ylabel='embedding_y2'>

# %% [markdown]
# ### <font color='green'> 4.3.2 Tree-Based Embedding

# %%
from sklearn import ensemble as en

# %%
#training dataset
X = df4[cols_selected].drop(columns=['gross_revenue'], axis=1)

y = df4['gross_revenue']

#model definition
rf_model = en.RandomForestRegressor(n_estimators=100, random_state=42)

#model training
rf_model.fit(X,y)


#Leaf(folhas)
df_leaf = pd.DataFrame(rf_model.apply(X))

# %%
reducer = TSNE(n_components=2, 
            random_state=42,
            n_jobs=-1)

#embedding

embedding = reducer.fit_transform(df_leaf )

df_tree = pd.DataFrame()
df_tree['embedding_x2'] = embedding[:,0]
df_tree['embedding_y2'] = embedding[:,1]

#plot
plt.figure(figsize=(16,8))
sns.scatterplot(x='embedding_x2', 
                y='embedding_y2',  
                data = df_tree)
# Out:
# <AxesSubplot:xlabel='embedding_x2', ylabel='embedding_y2'>

# %% [markdown]
# # <font color='red'> 6.0. Data Preparation </font>

# %%
df5 = df_tree.copy()

# %%
df5
# Out:
#       embedding_x2  embedding_y2
# 0        -0.513508    -46.704315
# 1       -21.127197     11.274652
# 2        45.485142    -31.858820
# 3        33.733624     43.352848
# 4       -51.338024    -27.798956
# ...            ...           ...
# 2979     10.161382     12.722069
# 2980     57.898247     19.828751
# 2981     32.009109     -4.351998
# 2982      6.853421    -24.968904
# 2983    -67.739151      1.794421
#
# [2984 rows x 2 columns]

# %%
df6 = df_tree

# %% [markdown]
# # <font color='red'> 7.0. Hyperparameter Fine-Tunning </font>

# %%
X = df6

# %%
X.head()
# Out:
#    embedding_x2  embedding_y2
# 0     -0.513508    -46.704315
# 1    -21.127197     11.274652
# 2     45.485142    -31.858820
# 3     33.733624     43.352848
# 4    -51.338024    -27.798956

# %%
clusters = np.arange(2, 25, 1)

# %% [markdown]
# ## 7.1. Kmeans

# %%
kmeans_list = []
for k in clusters:
    
    #model definition
    kmeans_model = cl.KMeans(n_clusters=k)
    
    #model training
    kmeans_model.fit(X)
    
    #model predict
    labels = kmeans_model.predict(X)
    
    #model performance
    sil = m.silhouette_score(X, labels, metric='euclidean')
    kmeans_list.append(sil)

# %%
plt.plot(clusters, kmeans_list, linestyle='--', marker='o', color='b')
plt.xlabel('k');
plt.ylabel('Silhouette Score');
plt.title('Silhouette Score x K')
# Out:
# Text(0.5, 1.0, 'Silhouette Score x K')

# %% [markdown]
# ## 7.2. GMM

# %%
from sklearn import mixture as mx

# %%
gmm_list = []

for k in clusters:

    #model definition
    gmm_model = mx.GaussianMixture(n_components=k)
    
    #model training 
    gmm_model.fit(X)
    
    #model predict
    labels = gmm_model.predict(X)
    
    #model performance
    sil = m.silhouette_score(X, labels, metric='euclidean')
    gmm_list.append(sil)

# %%
plt.plot(clusters, gmm_list, linestyle='--', marker='o', color='b')
plt.xlabel('k');
plt.ylabel('Silhouette Score');
plt.title('Silhouette Score x K')
# Out:
# Text(0.5, 1.0, 'Silhouette Score x K')

# %% [markdown]
# ## 7.3. Hierarchical Clustering

# %%
from scipy.cluster import hierarchy as hc

# %%
#model definition and training 
hc_model =hc.linkage(X, 'ward')

# %%
#hc.dendrogram(
#    hc_model,
#    leaf_rotation=90,
#    leaf_font_size=8)

#plt.figure(figsize=(16,8))

#plt.plot()

# %%
hc.dendrogram(
    hc_model,
    truncate_mode='lastp',
    p=12,
    leaf_rotation=90,
    leaf_font_size=8,
    show_contracted=True)

plt.figure(figsize=(16,8))

plt.show()

# %% [markdown]
# ### 7.3.1. HClustering Silhouette Score

# %%
hc_list = []
for k in clusters:

    #model definition and training
    hc_model = hc.linkage(X, 'ward')

    #model predict
    labels = hc.fcluster(hc_model, k, criterion='maxclust')

    #metrics
    sil = m.silhouette_score(X, labels, metric='euclidean')
    hc_list.append(sil)

# %%
plt.plot(clusters, hc_list, linestyle='--', marker='o', color='b')

# %% [markdown]
# ## 7.4. DBSCAN

# %% [raw]
# eps=0.2
# min_samples=20
#
# #model definition
# dbscan_model = DBSCAN(eps=eps, min_samples=min_samples)
# dbscan_model.fit(X)
# #mode training and predict
# labels = dbscan_model.labels_
#
# sil = m.silhouette_score(X, labels, metric='euclidean')
#
# print(f'Silhouette Score: {sil}')
# print(f'Number of Clusters: {len(np.unique(labels))}')
# print(np.unique(labels))

# %%
from sklearn.neighbors import NearestNeighbors

# %%
neighbors = NearestNeighbors(n_neighbors = min_samples).fit(X)
distances, indices = neighbors.kneighbors(X)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %% [markdown]
# ## 7.5. Results

# %%
df_results = pd.DataFrame(
{'Kmeans' : kmeans_list,
 'GMM' : gmm_list,
 'HC' : hc_list}
).T

df_results.columns = clusters

# %%
df_results.style.highlight_max(color='lightgreen', axis=1)
# Out:
# <style type="text/css">
# #T_17225_row0_col22, #T_17225_row1_col17, #T_17225_row2_col21 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_17225">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17225_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_17225_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_17225_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_17225_level0_col3" class="col_heading level0 col3" >5</th>
#       <th id="T_17225_level0_col4" class="col_heading level0 col4" >6</th>
#       <th id="T_17225_level0_col5" class="col_heading level0 col5" >7</th>
#       <th id="T_17225_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_17225_level0_col7" class="col_heading level0 col7" >9</th>
#       <th id="T_17225_level0_col8" class="col_heading level0 col8" >10</th>
#       <th id="T_17225_level0_col9" class="col_heading level0 col9" >11</th>
#       <th id="T_17225_level0_col10" class="col_heading level0 col10" >12</th>
#       <th id="T_17225_level0_col11" class="col_heading level0 col11" >13</th>
#       <th id="T_17225_level0_col12" class="col_heading level0 col12" >14</th>
#       <th id="T_17225_level0_col13" class="col_heading level0 col13" >15</th>
#       <th id="T_17225_level0_col14" class="col_heading level0 col14" >16</th>
#       <th id="T_17225_level0_col15" class="col_heading level0 col15" >17</th>
#       <th id="T_17225_level0_col16" class="col_heading level0 col16" >18</th>
#       <th id="T_17225_level0_col17" class="col_heading level0 col17" >19</th>
#       <th id="T_17225_level0_col18" class="col_heading level0 col18" >20</th>
#       <th id="T_17225_level0_col19" class="col_heading level0 col19" >21</th>
#       <th id="T_17225_level0_col20" class="col_heading level0 col20" >22</th>
#       <th id="T_17225_level0_col21" class="col_heading level0 col21" >23</th>
#       <th id="T_17225_level0_col22" class="col_heading level0 col22" >24</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17225_level0_row0" class="row_heading level0 row0" >Kmeans</th>
#       <td id="T_17225_row0_col0" class="data row0 col0" >0.365207</td>
#       <td id="T_17225_row0_col1" class="data row0 col1" >0.400436</td>
#       <td id="T_17225_row0_col2" class="data row0 col2" >0.421186</td>
#       <td id="T_17225_row0_col3" class="data row0 col3" >0.433139</td>
#       <td id="T_17225_row0_col4" class="data row0 col4" >0.437196</td>
#       <td id="T_17225_row0_col5" class="data row0 col5" >0.459278</td>
#       <td id="T_17225_row0_col6" class="data row0 col6" >0.479270</td>
#       <td id="T_17225_row0_col7" class="data row0 col7" >0.499570</td>
#       <td id="T_17225_row0_col8" class="data row0 col8" >0.501303</td>
#       <td id="T_17225_row0_col9" class="data row0 col9" >0.499170</td>
#       <td id="T_17225_row0_col10" class="data row0 col10" >0.519606</td>
#       <td id="T_17225_row0_col11" class="data row0 col11" >0.534439</td>
#       <td id="T_17225_row0_col12" class="data row0 col12" >0.532155</td>
#       <td id="T_17225_row0_col13" class="data row0 col13" >0.543903</td>
#       <td id="T_17225_row0_col14" class="data row0 col14" >0.556427</td>
#       <td id="T_17225_row0_col15" class="data row0 col15" >0.554756</td>
#       <td id="T_17225_row0_col16" class="data row0 col16" >0.569184</td>
#       <td id="T_17225_row0_col17" class="data row0 col17" >0.569187</td>
#       <td id="T_17225_row0_col18" class="data row0 col18" >0.568950</td>
#       <td id="T_17225_row0_col19" class="data row0 col19" >0.571948</td>
#       <td id="T_17225_row0_col20" class="data row0 col20" >0.572378</td>
#       <td id="T_17225_row0_col21" class="data row0 col21" >0.562953</td>
#       <td id="T_17225_row0_col22" class="data row0 col22" >0.576332</td>
#     </tr>
#     <tr>
#       <th id="T_17225_level0_row1" class="row_heading level0 row1" >GMM</th>
#       <td id="T_17225_row1_col0" class="data row1 col0" >0.366254</td>
#       <td id="T_17225_row1_col1" class="data row1 col1" >0.375922</td>
#       <td id="T_17225_row1_col2" class="data row1 col2" >0.381340</td>
#       <td id="T_17225_row1_col3" class="data row1 col3" >0.367042</td>
#       <td id="T_17225_row1_col4" class="data row1 col4" >0.369539</td>
#       <td id="T_17225_row1_col5" class="data row1 col5" >0.389164</td>
#       <td id="T_17225_row1_col6" class="data row1 col6" >0.468167</td>
#       <td id="T_17225_row1_col7" class="data row1 col7" >0.397461</td>
#       <td id="T_17225_row1_col8" class="data row1 col8" >0.438288</td>
#       <td id="T_17225_row1_col9" class="data row1 col9" >0.445999</td>
#       <td id="T_17225_row1_col10" class="data row1 col10" >0.481072</td>
#       <td id="T_17225_row1_col11" class="data row1 col11" >0.499771</td>
#       <td id="T_17225_row1_col12" class="data row1 col12" >0.506935</td>
#       <td id="T_17225_row1_col13" class="data row1 col13" >0.522363</td>
#       <td id="T_17225_row1_col14" class="data row1 col14" >0.510906</td>
#       <td id="T_17225_row1_col15" class="data row1 col15" >0.542723</td>
#       <td id="T_17225_row1_col16" class="data row1 col16" >0.547437</td>
#       <td id="T_17225_row1_col17" class="data row1 col17" >0.562254</td>
#       <td id="T_17225_row1_col18" class="data row1 col18" >0.490434</td>
#       <td id="T_17225_row1_col19" class="data row1 col19" >0.549041</td>
#       <td id="T_17225_row1_col20" class="data row1 col20" >0.549891</td>
#       <td id="T_17225_row1_col21" class="data row1 col21" >0.534130</td>
#       <td id="T_17225_row1_col22" class="data row1 col22" >0.526754</td>
#     </tr>
#     <tr>
#       <th id="T_17225_level0_row2" class="row_heading level0 row2" >HC</th>
#       <td id="T_17225_row2_col0" class="data row2 col0" >0.337910</td>
#       <td id="T_17225_row2_col1" class="data row2 col1" >0.364666</td>
#       <td id="T_17225_row2_col2" class="data row2 col2" >0.406231</td>
#       <td id="T_17225_row2_col3" class="data row2 col3" >0.413084</td>
#       <td id="T_17225_row2_col4" class="data row2 col4" >0.415910</td>
#       <td id="T_17225_row2_col5" class="data row2 col5" >0.426522</td>
#       <td id="T_17225_row2_col6" class="data row2 col6" >0.451518</td>
#       <td id="T_17225_row2_col7" class="data row2 col7" >0.477907</td>
#       <td id="T_17225_row2_col8" class="data row2 col8" >0.501874</td>
#       <td id="T_17225_row2_col9" class="data row2 col9" >0.510840</td>
#       <td id="T_17225_row2_col10" class="data row2 col10" >0.520673</td>
#       <td id="T_17225_row2_col11" class="data row2 col11" >0.534615</td>
#       <td id="T_17225_row2_col12" class="data row2 col12" >0.534852</td>
#       <td id="T_17225_row2_col13" class="data row2 col13" >0.534341</td>
#       <td id="T_17225_row2_col14" class="data row2 col14" >0.535355</td>
#       <td id="T_17225_row2_col15" class="data row2 col15" >0.541466</td>
#       <td id="T_17225_row2_col16" class="data row2 col16" >0.545891</td>
#       <td id="T_17225_row2_col17" class="data row2 col17" >0.562265</td>
#       <td id="T_17225_row2_col18" class="data row2 col18" >0.572593</td>
#       <td id="T_17225_row2_col19" class="data row2 col19" >0.571120</td>
#       <td id="T_17225_row2_col20" class="data row2 col20" >0.581949</td>
#       <td id="T_17225_row2_col21" class="data row2 col21" >0.588933</td>
#       <td id="T_17225_row2_col22" class="data row2 col22" >0.581888</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 7.5.1. MinMaxSacaler

# %% [markdown]
# ## 8.1. Within-Cluster Sum of Square (WSS)

# %%
wss = []
for k in clusters:
    #model definition
    kmeans = cl.KMeans( init='random', n_clusters=k, n_init=10, max_iter=300, random_state=42)
    
    #model training
    kmeans.fit(X)
    
    #validation
    wss.append(kmeans.inertia_)
    
#plot wss
plt.plot(clusters, wss, linestyle='--', marker='o', color='b')
plt.xlabel('k')
plt.ylabel('Within-Cluster Sum of Square')
plt.title('WSS vs K')
# Out:
# Text(0.5, 1.0, 'WSS vs K')

# %%
kmeans = KElbowVisualizer(cl.KMeans(), k=clusters, timings=False)
kmeans.fit(X)
kmeans.show();

# %% [markdown]
# ## 8.2. Silhouette Analysis

# %% [raw]
# fig, ax = plt.subplots(3, 2)
# fig.set_size_inches(25, 20)
#
# for k in clusters:
#     q, mod = divmod(k, 2)
#
#     ax[q-1, mod].set_xlim([-0.1, 1])
#     ax[q-1, mod].set_ylim([0, len(X) + (k+1)*10])
#
#     #model definition & training
#     hc_model = hc.linkage(X, 'ward')
#
#     #model predict
#     labels = hc.fcluster(hc_model, k, criterion='maxclust')
#
#     #performance
#     ss= m.silhouette_score(X, labels, metric='euclidean')
#     print(f'For K = {k}. Silhouette Score: {ss}')
#
#     samples_silhouette_values = m.silhouette_samples(X, labels)
#
#     y_lower = 10
#     for i in range(k):
#
#         #select clusters
#         ith_samples_silhouette_values = samples_silhouette_values[labels == i]
#
#         #sort values
#         ith_samples_silhouette_values.sort()
#
#         #size clusters
#         size_cluster_i = ith_samples_silhouette_values.shape[0]
#         y_upper = y_lower + size_cluster_i
#
#         cmap = cm.get_cmap('Spectral')
#         color = cmap(i / k)
#
#         ax[q-1, mod].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_samples_silhouette_values)
#
#         y_lower = y_upper + 10
#
#     ax[q-1, mod].set_yticks([])
#     ax[q-1, mod].set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

# %% [raw]
# fig, ax = plt.subplots(3,2, figsize=(25, 18))
# for k in clusters:
#     km = cl.KMeans(n_clusters=k, init='random', n_init=10, max_iter=100, random_state=42)
#     q, mod = divmod (k, 2)
#
#     visualizer = SilhouetteVisualizer(km, color= 'yellowbrick', ax=ax[q-1][mod])
#     visualizer.fit(X)
#     visualizer.finalize()

# %% [markdown]
# # <font color='red'> 9.0. Model Training </font>

# %% [markdown]
# ## 9.1. K-Means

# %%
# Model Definition
k = 8
kmeans = cl.KMeans(init='random',n_clusters=k, n_init=10, max_iter=300, random_state=42)

#model training
kmeans.fit(X)

#clustering
labels = kmeans.labels_

# %% [markdown]
# ## 9.2. Cluster Validation

# %%
# WSS
print(f'WSS values: {kmeans.inertia_}')
print(f"SS value: {m.silhouette_score(X, labels, metric='euclidean')}")
# Out:
# WSS values: 809431.125
# SS value: 0.4799715578556061

# %% [markdown]
# # <font color='red'> 10.0. Cluster Analysis </font>

# %%
df10 = X.copy()
df10['cluster'] = labels
df10.head()
# Out:
#    embedding_x2  embedding_y2  cluster
# 0     -0.513508    -46.704315        1
# 1    -21.127197     11.274652        2
# 2     45.485142    -31.858820        0
# 3     33.733624     43.352848        5
# 4    -51.338024    -27.798956        3

# %%
df10.shape
# Out:
# (2984, 3)

# %%
df4 = df4.reset_index(drop=True)

# %%
df4['cluster'] = df10['cluster']

# %% [markdown]
# ## 10.1. Visualization Inspection

# %%
sns.scatterplot(x='embedding_x2', y='embedding_y2',hue='cluster', data=df10, palette='deep')
# Out:
# <AxesSubplot:xlabel='embedding_x2', ylabel='embedding_y2'>

# %% [markdown]
# ## 10.1. Visualization Inspection

# %%
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
visualizer.fit(X)
visualizer.finalize()

# %% [markdown]
# ## 10.2. 2d plot

# %%
df_viz = df10.copy()
#sns.pairplot(df_viz, hue='cluster')

# %% [markdown]
# ## 10.3. UMAP - t-SNE

# %%
from sklearn.decomposition import PCA

# %%
#reducer = UMAP(random_state=42)
#embedding = reducer.fit_transform(x)

#embedding
#df_viz['embedding_x'] = embedding[:,0]
#df_viz['embedding_y'] = embedding[:,1]

#plot UMAP

sns.scatterplot(x='embedding_x2', y='embedding_y2', 
                hue='cluster', 
                palette=sns.color_palette('hls', n_colors=len(df10['cluster'].unique())), 
                data = df_viz)
# Out:
# <AxesSubplot:xlabel='embedding_x2', ylabel='embedding_y2'>

# %% [raw]
# from sklearn.manifold import TSNE
#
#
#
# tsne = TSNE(n_components=2, random_state=42)
# embedding = tsne.fit_transform(X )
# df_viz['embedding_x2'] = embedding[:,0]
# df_viz['embedding_y2'] = embedding[:,1]
# sns.scatterplot(x='embedding_x2', y='embedding_y2',
#                 hue='cluster',
#                 palette=sns.color_palette('hls', n_colors=len(df_viz['cluster'].unique())),
#                 data = df_viz)

# %% [markdown]
# ## 10.2. Cluster Profile

# %%
df10.cluster.unique()
# Out:
# array([1, 2, 0, 5, 3, 7, 4, 6])

# %%
df4['cluster'] = df10['cluster']

# %%
# Number of Cluster
df_cluster = df4[['customer_id', 'cluster']].groupby('cluster').count().reset_index()
df_cluster['perc_customer'] = 100* (df_cluster['customer_id'] / df_cluster['customer_id'].sum()).round(4)

# AVG Gross Revenue
df_avg_gross = df4[['gross_revenue', 'cluster']].groupby('cluster').mean().reset_index().round(4)
df_cluster = pd.merge(df_cluster, df_avg_gross, how='inner', on='cluster')

#AVG recency days
df_recency = df4[['recency_days', 'cluster']].groupby('cluster').mean().reset_index().round(4)
df_cluster = pd.merge(df_cluster, df_recency, how='inner', on='cluster')

#qtde_product
qtde_product = df4[['qtde_produto', 'cluster']].groupby('cluster').mean().reset_index().round(4)
df_cluster = pd.merge(df_cluster, qtde_product, how='inner', on='cluster')

#frequency
frequency = df4[['frequency', 'cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, frequency, how='inner', on='cluster')


#returns
returns = df4[['qtde_returns', 'cluster']].groupby('cluster').mean().reset_index()
df_cluster = pd.merge(df_cluster, returns, how='inner', on='cluster')

# %%
df_cluster.head(8)
# Out:
#    cluster  customer_id  perc_customer  gross_revenue  recency_days  \
# 0        0          379          12.70     12107.1468       30.2850
# 1        1          338          11.33      3486.3217       31.7485
# 2        2          398          13.34      2163.0013       42.3392
# 3        3          565          18.93       354.5886      115.6088
# 4        4          378          12.67       609.9198       83.2354
# 5        5          307          10.29       842.4607       74.8046
# 6        6          305          10.22      1019.2707       67.5344
# 7        7          314          10.52      1620.5046       41.5510
#
#    qtde_produto  frequency  qtde_returns
# 0      168.6755   0.072663    181.509235
# 1      134.3462   0.087392     33.082840
# 2       96.4698   0.042491     28.010050
# 3       21.4673   0.266766      5.522124
# 4       43.3466   0.144167      5.685185
# 5       51.7785   0.090500      6.755700
# 6       56.8852   0.086954     12.563934
# 7       85.4682   0.039299     17.452229

# %%
df_cluster.head(8)
# Out:
#       customer_id  gross_revenue  recency_days  invoice_no  qtde_items  \
# 0           17850        5391.21         372.0        34.0      1733.0
# 1           13047        3237.54          31.0        10.0      1391.0
# 2           12583        7281.38           2.0        15.0      5060.0
# 3           13748         948.25          95.0         5.0       439.0
# 4           15100         876.00         333.0         3.0        80.0
# ...           ...            ...           ...         ...         ...
# 2979        12479         527.20          11.0         1.0       385.0
# 2980        14126         706.13           7.0         3.0       508.0
# 2981        13521        1093.65           1.0         3.0       736.0
# 2982        15060         303.09           8.0         4.0       263.0
# 2983        12558         269.96           7.0         1.0       196.0
#
#       qtde_produto  avg_ticket  avg_recency_days  frequency  qtde_returns  \
# 0             21.0   18.152222         35.500000  17.000000          40.0
# 1            106.0   18.822907         26.307692   0.029155          36.0
# 2            115.0   29.479271         21.823529   0.040323          51.0
# 3             24.0   33.866071         92.666667   0.017921           0.0
# 4              1.0  292.000000          8.600000   0.073171          22.0
# ...            ...         ...               ...        ...           ...
# 2979          31.0   17.006452          4.000000   1.000000          34.0
# 2980          14.0   47.075333          3.000000   0.750000          50.0
# 2981         313.0    2.508372          4.500000   0.300000           0.0
# 2982          81.0    2.504876          1.000000   2.000000           0.0
# 2983          11.0   24.541818          6.000000   1.000000         196.0
#
#       avg_basket_size  avg_unique_basket_size  cluster
# 0           50.970588                0.617647        1
# 1          139.100000               10.600000        2
# 2          337.333333                7.666667        0
# 3           87.800000                4.800000        5
# 4           26.666667                0.333333        3
# ...               ...                     ...      ...
# 2979       385.000000               31.000000        5
# 2980       169.333333                4.666667        6
# 2981       245.333333              104.333333        0
# 2982        65.750000               20.250000        4
# 2983       196.000000               11.000000        3
#
# [2984 rows x 13 columns]

# %%
#organizando o cluster pelo gross_revenue
df_cluster_ordenado = df_cluster.sort_values(by='gross_revenue', ascending=False).reset_index(drop=True)
df_cluster_ordenado

# %%
#mudando o index para ser o novo Cluster
df_cluster_ordenado['index'] = df_cluster_ordenado.index
df_cluster_ordenado

# %%
#juntando o df_cluster com o df4
df4 = pd.merge(df4, df_cluster_ordenado[['cluster', 'index']], on='cluster')
df4

# %%
df4 = df4.drop(['cluster'], axis=1)
df4 = df4.rename(columns={'index' : 'cluster'})
df4

# %%
# Carrega as funções usadas para autenticar e gerar  relatórios
from powerbiclient import Report, models
from powerbiclient import QuickVisualize, get_dataset_config, Report
from powerbiclient.authentication import DeviceCodeLoginAuthentication

# %%
# Define a autenticação no Power BI Service
device_auth = DeviceCodeLoginAuthentication()

# %%
# Cria o relatório no Power BI
relatorio_PBI = QuickVisualize(get_dataset_config(df4))

# %%
# Renderiza (visualiza) o relatório
relatorio_PBI

# %% [markdown]
# ## Cluster 01 : (Candidato a Insider)
#     - Número de customers :6 (0.14% do customers)
#     - Recência em média :  7 dias
#     - Compras em média :  89 compras
#     - Receita em média : $182.182,00 dolares
#
# ## Cluster 01 : (Candidato a Insider)
#     - Número de customers : 31 (0.7% do customers)
#     - Recência em média : 14 dias
#     - Compras em média : 53 compras
#     - Receita em média : $40.543,52 dolares
#
# ## Cluster 01 : (Candidato a Insider)
#     - Número de customers : 4.335 (99% do customers)
#     - Recência em média : 92 dias
#     - Compras em média : 5 compras
#     - Receita em média : $ 1.372,57 dolares

# %% [markdown]
# # 11. Análise Exploratória de Dados

# %% [markdown]
# ## 10.1. MindMap de hipoteses

# %% [markdown]
# ## 10.2. Hipóteses de Negócio

# %% [markdown]
# 1. Afirmação
# 2. Comparação entre variaveis
# 3. Valor base de comparação

# %% [markdown]
# ### 10.2.1. Hipóteses Compra

# %% [markdown]
# 1. Os clientes de cluster insiders usam cartão de crédito em 80% das compras.
# 2. Os clientes de cluster insiders possuem um ticket médio de 10 % acima do cluster more products.
# 3. Os clientes de cluster insiders possuem um basket size acima de 5 produtos.
# 4. Os clientes de cluster insiders possuem um volume de compras acima de 10% do total
# 5. Os clientes de cluster insiders tem um número de devolução abaixo da média da base total de clientes

# %% [markdown]
# ### 10.2.2. Hipóteses Cliente

# %% [markdown]
# 1. Os clientes de cluster insiders correspondem a 60% do estado civil de solteiro
# 2. **10% dos clientes de cluster insiders estão na faixa de 24-35 anos**
# 3. **40% das localidades de entrega dos clientes de cluster insiders estão dentro de um raio de 50 km**
# 4. 5% dos clientes do cluster insiders recebem mais de 100 mil por ano
# 5. 90% dos clientes do cluster insedes tem ensino superior completo.

# %% [markdown]
# ### 10.2.3. Hipóteses Produto

# %% [markdown]
# 1. 30% dos produtos em pacotes grandes são comprados pelos clientes do cluster insiders
# 2. A mediana dos preços dos produtos comprados pelos clientes do cluster insider é 10% maior
#    do que a mediana de todos os preços dos produtos
# 3. O percentil do preço dos produtos comprados pelos clientes insiders
# 4. O peso médio dos produtos comprados pelos clientes do cluster insiders é maior do que o peso médio dos produtos
#    comprados no geral
# 5. A idade média dos produtos comprados pelos clientes do cluster insiders é menor que 15 dias

# %% [markdown]
# ## 1. Quem são as pessoas elegíveis para participar do programa de Insiders ?

# %%
df4.loc[df4['cluster'] == 1, 'customer_id'].head()
# Out:
# 0     17850
# 5     15291
# 7     17809
# 9     14527
# 21    13448
# Name: customer_id, dtype: int32

# %% [markdown]
# ## 2. Quantos Clientes farão parte do grupo?

# %%
len(df4.loc[df4['cluster'] == 0])
# Out:
# 379

# %% [markdown]
# ## 3.Quais são as caracteristicas do grupo insiders

# %%
df_cluster.loc[df_cluster['cluster'] == 0]
# Out:
#    cluster  customer_id  perc_customer  gross_revenue  recency_days  \
# 0        0          379           12.7     12107.1468        30.285
#
#    qtde_produto  frequency  qtde_returns
# 0      168.6755   0.072663    181.509235

# %% [markdown]
# ## 4. Qual a porcentagem de contribuição do faturamento, vinda do Insiders?

# %%
df_insiders_gmv = df4.loc[df4['cluster'] == 0, 'gross_revenue'].sum()
df_gmv_all = df4['gross_revenue'].sum()
percentual = df_insiders_gmv / df_gmv_all
percentual
# Out:
# 0.5639117881303903
